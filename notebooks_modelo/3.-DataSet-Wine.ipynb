# %% [markdown]
# # Wine
#
# En este notebook es una exploracion de como se usa el dataset de wine usando el modelo de manhattan para el calculo de distancias dónde se utilizara para ejemplificar como trabajara este modelo en un dataset mas grande que el de iris
